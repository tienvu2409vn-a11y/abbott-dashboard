# %%
#bai_1
Your_name = input("nhap_ten_cua_ban")
word = "Hello,"
exclamation_mark = "!"
print(word + Your_name + exclamation_mark)
# Out:
# Hello,Tien!

# %%
#bai_2
x = input("the_1st_number") #string
y = input("the_2nd_number")

int (x) + int (y)
# Out:
# 6

# %%
#bai_3
x = input("the_1st_number") #string

if int(x) % 2 == 0:   # nếu chia 2 dư 0
    print("so_chan")
else:
    print("so_le")
# Out:
# so_chan

# %%
#bai_4

x = input("the_1st_number") #string
y = input("the_2nd_number")

max_value = int(x) if int(x) >int (y) else int(y)
print (max_value)
# Out:
# 12

# %%
#bai_5
x = input("the_1st_number") #string

if int (x) > 0:   # nếu x > 0 => dương
    print("duong")
elif int (x) < 0:   # nếu x > 0 => âm
    print("duong")

else:
    print("bằng 0")
# Out:
# bằng 0

# %%
#bai_6

chieu_dai = input("nhap chieu dai") #string
chieu_rong = input("nhap chieu rong")

print(int(chieu_dai) * int(chieu_rong))

# %%
#bai_7

ban_kinh = input("nhap ban kinh") #string

chu_vi = "chu vi"
dien_tich = "dien tich"

print(str(chu_vi)) 
print( 2*int(ban_kinh) * 3.14)

print(str(dien_tich)) 
print( int(ban_kinh)**2 * 3.14)

# %%
#bai_8

a = input("the_1st_number") #string
b = input("the_2nd_number")
c = input("the_3nd_number")

if int(a) > int(b) and int(a) > int(c):
  max_value = int(a)
elif int(b) > int(a) and int(b) > int(c):
  max_value = int(b)
else:max_value = int(c)


print (max_value)

# %%
#bai_9
x = input("the_1st_number")  # string

if int(x) >= 0:
    absolute = int(x)
else:
    absolute = int(x) * -1

print(absolute)

# %%
#bai_10
x = input("the_1st_number") #string

if int(x) % 4 == 0:   # nếu chia 4 dư 0
    print(x + " la nam nhuan")
else:
    print(x + " khong phai nam nhuan")

# %%
#bai_11
x = input("the_1st_number") #string
print(int(x) // 100 % 10) #chia 100 lấy số hàng đơn vị, sau đó chia 10 lấy số dư
# Out:
# 2

# %%
#bai_12
x = input("the_1st_number") #string

if int(x) % 3 == 0   or int(x) % 7 == 0: # nếu chia 3 hoac 7 dư 0
    print( x + " chia hết cho 3 hoặc 7")


else:
    print("wrong")
